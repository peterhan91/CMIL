# %%
import pandas as pd
import glob
import os
import lmdb
import pickle
import ast
from datasets import load_dataset
from tqdm import tqdm
import numpy as np
from torch.utils.data import Dataset, DataLoader
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df_train = pd.read_csv('../csvs/dataset_multi_abnormality_labels_train_predicted_labels.csv')
df_val = pd.read_csv('../csvs/dataset_multi_abnormality_labels_valid_predicted_labels.csv')
df_val.head()
# Out:
#            VolumeName  Medical material  Arterial wall calcification  \
# 0  valid_1_a_1.nii.gz                 0                            0
# 1  valid_1_a_2.nii.gz                 0                            0
# 2  valid_2_a_1.nii.gz                 0                            0
# 3  valid_2_a_2.nii.gz                 0                            0
# 4  valid_3_a_1.nii.gz                 0                            0
#
#    Cardiomegaly  Pericardial effusion  Coronary artery wall calcification  \
# 0             0                     0                                   0
# 1             0                     0                                   0
# 2             0                     0                                   0
# 3             0                     0                                   0
# 4             0                     0                                   0
#
#    Hiatal hernia  Lymphadenopathy  Emphysema  Atelectasis  Lung nodule  \
# ...

# %%
df_val['patient_id'] = df_val['VolumeName'].apply(lambda x: int(x.split('_')[1]))
list_val_val, list_val_test = train_test_split(df_val['patient_id'].unique(), test_size=0.95, random_state=12)
len(list_val_val), len(list_val_test)
df_val_val = df_val[df_val['patient_id'].isin(list_val_val)]
df_val_test = df_val[df_val['patient_id'].isin(list_val_test)]
len(df_val_val), len(df_val_test)
print(np.intersect1d(df_val_val['patient_id'], df_val_test['patient_id']))
# Out:
# (65, 1239)
# (161, 2878)
# []

# %%
df_val_val.to_csv('../csvs/dataset_multi_abnormality_labels_validation_set.csv', index=False)
df_val_test.to_csv('../csvs/dataset_multi_abnormality_labels_test_set.csv', index=False)
